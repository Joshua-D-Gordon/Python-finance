# %% [markdown]
# ### Portfolio vs index's

# %%
#importing modules and packages
import numpy as np
import pandas as pd
from pandas_datareader import data as wd
import matplotlib.pyplot as plt

# %%
#list of stock tickers
tickers = ['EPR', 'EPRT', 'VICI', 'AHH', 'HOM-U.TO', 'CLPR', 'TCN', 'ARE', 'IVQ-U.TO', 'MPW', 'GMRE', 'OUT', 'UNIT', 'WSR', 'SPG', 'STAG', 'SAFE', 'FPI']
#creating dataframe
portfolio_data = pd.DataFrame()

import datetime
#using yahoo finance
import yfinance as yf

yf.pdr_override()
#statring date for time frame
start = datetime.datetime(2018, 1, 1).date()
#inserting data
for t in tickers:
    portfolio_data[t] = wd.get_data_yahoo(t, start)['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
portfolio_data.info()
#cheeckign data is clean and no non missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1487 entries, 2018-01-02 to 2023-11-28
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EPR       1487 non-null   float64
#  1   EPRT      1369 non-null   float64
#  2   VICI      1487 non-null   float64
#  3   AHH       1487 non-null   float64
#  4   HOM-U.TO  1361 non-null   float64
#  5   CLPR      1487 non-null   float64
#  6   TCN       540 non-null    float64
#  7   ARE       1487 non-null   float64
#  8   IVQ-U.TO  1456 non-null   float64
#  9   MPW       1487 non-null   float64
#  10  GMRE      1487 non-null   float64
#  11  OUT       1487 non-null   float64
#  12  UNIT      1487 non-null   float64
#  13  WSR       1487 non-null   float64
#  14  SPG       1487 non-null   float64
#  15  STAG      1487 non-null   float64
#  16  SAFE      1487 non-null   float64
#  17  FPI       1487 non-null   float64
# dtypes: float64(18)
# memory usage: 220.7 KB

# %%
# list of index's ticker symbols
indexs = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE']

#creating data frame
index_data = pd.DataFrame()

import datetime
#using yahoo finance
import yfinance as yf

yf.pdr_override()
#start time in regards to date time frame
start = datetime.datetime(2018, 1, 1).date()

#inserting data
for i in indexs:
    index_data[i] = wd.get_data_yahoo(i, start)['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
index_data.info()
##checking data is clean and no non missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1487 entries, 2018-01-02 to 2023-11-28
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ^GSPC   1487 non-null   float64
#  1   ^IXIC   1487 non-null   float64
#  2   ^GDAXI  1462 non-null   float64
#  3   ^FTSE   1457 non-null   float64
# dtypes: float64(4)
# memory usage: 58.1 KB

# %%
(index_data / index_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()
#plowing normalized index's data for fair comparison

# %%
(portfolio_data / portfolio_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()
#plotting portfolio data normalized for fair comparison

# %%
#all tickers index's and portfolio
all = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE','EPR', 'EPRT', 'VICI', 'AHH', 'HOM-U.TO', 'CLPR', 'TCN', 'ARE', 'IVQ-U.TO', 'MPW', 'GMRE', 'OUT', 'UNIT', 'WSR', 'SPG', 'STAG', 'SAFE', 'FPI']

all_data = pd.DataFrame()

import datetime
import yfinance as yf

yf.pdr_override()

start = datetime.datetime(2018, 1, 1).date()

for a in all:
    all_data[a] = wd.get_data_yahoo(a, start)['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
all_data.info()
#cheecking data is clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1487 entries, 2018-01-02 to 2023-11-28
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ^GSPC     1487 non-null   float64
#  1   ^IXIC     1487 non-null   float64
#  2   ^GDAXI    1462 non-null   float64
#  3   ^FTSE     1457 non-null   float64
#  4   EPR       1487 non-null   float64
#  5   EPRT      1369 non-null   float64
#  6   VICI      1487 non-null   float64
#  7   AHH       1487 non-null   float64
#  8   HOM-U.TO  1361 non-null   float64
#  9   CLPR      1487 non-null   float64
#  10  TCN       540 non-null    float64
#  11  ARE       1487 non-null   float64
#  12  IVQ-U.TO  1456 non-null   float64
#  13  MPW       1487 non-null   float64
#  14  GMRE      1487 non-null   float64
#  15  OUT       1487 non-null   float64
#  16  UNIT      1487 non-null   float64
#  17  WSR       1487 non-null   float64
#  18  SPG       1487 non-null   float64
#  19  STAG      1487 non-null   float64
#  20  SAFE      1487 non-null   float64
#  21  FPI       1487 non-null   float64
# dtypes: float64(22)
# memory usage: 267.2 KB

# %%
(all_data /all_data.iloc[0] * 100).plot(figsize=(15,6))
plt.show()
#ploting all data

# %%
all_returns = (all_data / all_data.shift(1)) - 1
all_returns.tail()
# computing daily returns
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE       EPR      EPRT  \
# Date
# 2023-11-21 -0.002021 -0.005919 -0.000050 -0.001921 -0.014929  0.005563
# 2023-11-22  0.004061  0.004639  0.003603 -0.001671  0.005795  0.008936
# 2023-11-24  0.000597 -0.001052  0.004491  0.002504  0.010414  0.000422
# 2023-11-27 -0.001954 -0.000690 -0.003938 -0.003672 -0.015789 -0.004216
# 2023-11-28  0.000980  0.002861  0.001647 -0.000737 -0.002451 -0.005080
#
#                 VICI       AHH  HOM-U.TO      CLPR  ...  IVQ-U.TO       MPW  \
# Date                                                ...
# 2023-11-21 -0.013986 -0.018570  0.000000 -0.015487  ... -0.104167 -0.063918
# 2023-11-22  0.014539  0.009461 -0.009479  0.094382  ... -0.023256  0.002203
# 2023-11-24  0.001748  0.002812 -0.016268  0.010267  ...  0.000000  0.026374
# 2023-11-27  0.003489 -0.003738 -0.006809 -0.024390  ...  0.095238  0.032120
# 2023-11-28  0.015994  0.000000 -0.021548  0.010417  ...  0.000000 -0.012448
#
#                 GMRE       OUT      UNIT       WSR       SPG      STAG  \
# Date
# 2023-11-21 -0.007136 -0.021995 -0.007326 -0.001823 -0.008147 -0.012746
# 2023-11-22  0.005133 -0.012048 -0.003690  0.010959 -0.005339  0.005333
# 2023-11-24  0.000000  0.000813  0.007407  0.007227 -0.002147  0.003629
# 2023-11-27  0.009193  0.003249  0.009191 -0.008072  0.007200  0.006676
# 2023-11-28  0.005061  0.017004 -0.009107 -0.004521  0.003204 -0.009118
#
#                 SAFE       FPI
# Date
# 2023-11-21 -0.006353  0.018946
# 2023-11-22  0.030368  0.004850
# 2023-11-24  0.007756  0.017699
# 2023-11-27  0.005644 -0.001581
# 2023-11-28 -0.015306 -0.000792
#
# [5 rows x 22 columns]

# %%
all_annual_returns = all_returns.mean() * 250
all_annual_returns
#computing average annual returns based on 250 trading days
# Out:
# ^GSPC       0.109799
# ^IXIC       0.150056
# ^GDAXI      0.049282
# ^FTSE       0.008120
# EPR         0.133702
# EPRT        0.247273
# VICI        0.169007
# AHH         0.064571
# HOM-U.TO    0.079486
# CLPR        0.026768
# TCN        -0.158185
# ARE         0.037357
# IVQ-U.TO   -0.326540
# MPW        -0.037918
# GMRE        0.166555
# OUT         0.080017
# UNIT        0.050196
# WSR         0.101167
# SPG         0.095236
# STAG        0.136725
# SAFE       -0.009892
# FPI         0.179101
# dtype: float64

# %%
portfolio_returns = (portfolio_data / portfolio_data.shift(1)) - 1
portfolio_returns.head()
#computing portfolio daily returns
# Out:
#                  EPR  EPRT      VICI       AHH  HOM-U.TO      CLPR  TCN  \
# Date
# 2018-01-02       NaN   NaN       NaN       NaN       NaN       NaN  NaN
# 2018-01-03 -0.009924   NaN  0.002986 -0.008371       NaN -0.004000  NaN
# 2018-01-04 -0.018481   NaN  0.001984 -0.017532       NaN -0.009036  NaN
# 2018-01-05 -0.001276   NaN  0.000000 -0.003966       NaN  0.014184  NaN
# 2018-01-08 -0.000320   NaN  0.000000 -0.037824       NaN -0.002997  NaN
#
#                  ARE  IVQ-U.TO       MPW      GMRE       OUT      UNIT  \
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-01-03 -0.004695  0.004768 -0.002892 -0.010600 -0.009067 -0.009297
# 2018-01-04 -0.019950  0.013049 -0.017404  0.000000 -0.002179  0.003519
# 2018-01-05  0.002051 -0.001171 -0.019926  0.008333 -0.000873  0.002922
# 2018-01-08  0.002205  0.025791  0.002259  0.011806 -0.008304  0.000000
#
#                  WSR       SPG      STAG      SAFE       FPI
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN
# 2018-01-03 -0.000696 -0.004640  0.000369 -0.007073  0.000000
# 2018-01-04 -0.031337 -0.029251 -0.019919 -0.004452  0.000000
# 2018-01-05  0.007908  0.009304 -0.006399  0.006261 -0.012585
# 2018-01-08  0.017118  0.006542  0.000378  0.001778  0.018540

# %%
lst = ['EPR', 'EPRT', 'VICI', 'AHH', 'HOM-U.TO', 'CLPR', 'TCN', 'ARE', 'IVQ-U.TO', 'MPW', 'GMRE', 'OUT', 'UNIT', 'WSR', 'SPG', 'STAG', 'SAFE', 'FPI']
print(len(lst))
weights_one_to_three = 3+3+2+3+2+2+1+3+1+1+3+2+1+1+2+2+1+1
print(weights_one_to_three)
# Out:
# 18
# 34

# %%
slices = 1/34
portfolio_weights = np.array([3*slices, 3*slices, 2*slices, 3*slices, 2*slices, 2*slices, 1*slices, 3*slices, 1*slices, 1*slices, 3*slices, 2*slices, 1*slices, 1*slices, 2*slices, 2*slices, 1*slices, 1*slices])
print(sum(portfolio_weights))
# Out:
# 1.0

# %%
slices = 1/34
portfolio_weights = np.array([3*slices, 3*slices, 2*slices, 3*slices, 2*slices, 2*slices, 1*slices, 3*slices, 1*slices, 1*slices, 3*slices, 2*slices, 1*slices, 1*slices, 2*slices, 2*slices, 1*slices, 1*slices])
portfolio_r = np.dot(portfolio_returns, portfolio_weights)
portfolio_r
#assgining weights to portfolio (evenly distributed investing equally in each stock)
# Out:
# array([       nan,        nan,        nan, ..., 0.00379988, 0.001638  ,
#        0.0015642 ])

# %%
portfolio_annual_returns = portfolio_returns.mean() * 250
portfolio_annual_returns
#computing anuual portfolio returns
# Out:
# EPR         0.133702
# EPRT        0.247273
# VICI        0.169007
# AHH         0.064571
# HOM-U.TO    0.079486
# CLPR        0.026768
# TCN        -0.158185
# ARE         0.037357
# IVQ-U.TO   -0.326540
# MPW        -0.037918
# GMRE        0.166556
# OUT         0.080017
# UNIT        0.050196
# WSR         0.101167
# SPG         0.095236
# STAG        0.136725
# SAFE       -0.009892
# FPI         0.179101
# dtype: float64

# %%
index_returns = (index_data / index_data.shift(1)) - 1
index_returns.head()
#computing daily gains index's
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2018-01-02       NaN       NaN       NaN       NaN
# 2018-01-03  0.006399  0.008367  0.008299  0.003007
# 2018-01-04  0.004029  0.001752  0.014615  0.003233
# 2018-01-05  0.007034  0.008286  0.011524  0.003677
# 2018-01-08  0.001662  0.002919  0.003614 -0.003586

# %%
index_weights = np.array([0.25, 0.25, 0.25, 0.25])
index_r = np.dot(index_returns, index_weights)
index_r
#assigning weigts for index's
# Out:
# array([        nan,  0.00651815,  0.00590725, ...,  0.00163485,
#        -0.00256354,  0.00118772])

# %%
index_annual_returns = index_returns.mean() * 250
index_annual_returns
#avrage annual returns index's based on 250 trading days per year
# Out:
# ^GSPC     0.109799
# ^IXIC     0.150056
# ^GDAXI    0.049282
# ^FTSE     0.008120
# dtype: float64

# %%
portfolio_annual_return = str(round(np.dot(portfolio_annual_returns, portfolio_weights), 5)*100) + ' %'
print(portfolio_annual_return)
#portfolio annual returns
# Out:
# 8.591 %

# %%
index_annual_return = str(round(np.dot(index_annual_returns, index_weights), 5)*100) + ' %'
print(index_annual_return)
#index's annual returns
# Out:
# 7.931000000000001 %

# %% [markdown]
# # Conclusion
# ## based on the current research of this Mini project:
#
# #### the anuual rate of return of a evenily distributed portfolio containing the reits: from the date 2018/01/01 would produce a avrage annual rate of return of 8.591 %
#
# #### the anuual rate of return of a evenily distributed portfolio containing the Index's: [S&P 500, NASDAQ, DAX, FTSE 100] from the date 2018/01/01 would produce a avrage annual rate of return of 7.931000000000001 %

# %% [markdown]
# # internatonial vs S&P 500

# %%
#importing and making data frames
wsb_tickers = ['REI-UN.TO', 'DIR-UN.TO', 'NWH-UN.TO', 'NET-UN.V', 'NSR', 'BYG.L', 'SGRO.L', 'VNA.DE', 'LI.PA','CERT', 'BRNK.DE', 'TSM1T.TL', 'CBUS', 'T82U.SI']
snp_500 = ['^GSPC']
all_tickers = ['REI-UN.TO', 'DIR-UN.TO', 'NWH-UN.TO', 'NET-UN.V', 'NSR', 'BYG.L', 'SGRO.L', 'VNA.DE', 'LI.PA','CERT', 'BRNK.DE', 'TSM1T.TL', 'CBUS', 'T82U.SI', '^GSPC']

wsb_data = pd.DataFrame()
snp_data = pd.DataFrame()
all_d = pd.DataFrame()

import datetime
#using yahoo finance
import yfinance as yf

yf.pdr_override()
#start date in regards to time frame
start = datetime.datetime(2017, 1, 1).date()

for w in wsb_tickers:
    wsb_data[w] = wd.get_data_yahoo(w, start)['Adj Close']

for i in snp_500:
    snp_data[i] = wd.get_data_yahoo(i, start)['Adj Close']

for a in all_tickers:
    all_d[a] = wd.get_data_yahoo(a, start)['Adj Close']
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
wsb_data.info()
#checking data is clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1734 entries, 2017-01-03 to 2023-11-28
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   REI-UN.TO  1734 non-null   float64
#  1   DIR-UN.TO  1734 non-null   float64
#  2   NWH-UN.TO  1734 non-null   float64
#  3   NET-UN.V   1291 non-null   float64
#  4   NSR        544 non-null    float64
#  5   BYG.L      1703 non-null   float64
#  6   SGRO.L     1702 non-null   float64
#  7   VNA.DE     1707 non-null   float64
#  8   LI.PA      1721 non-null   float64
#  9   CERT       728 non-null    float64
#  10  BRNK.DE    1707 non-null   float64
#  11  TSM1T.TL   1341 non-null   float64
#  12  CBUS       1567 non-null   float64
#  13  T82U.SI    1685 non-null   float64
# dtypes: float64(14)
# memory usage: 203.2 KB

# %%
snp_data.info()
#checking data is clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1738 entries, 2017-01-03 to 2023-11-28
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ^GSPC   1738 non-null   float64
# dtypes: float64(1)
# memory usage: 27.2 KB

# %%
all_d.info()
#checking data is clean
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1734 entries, 2017-01-03 to 2023-11-28
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   REI-UN.TO  1734 non-null   float64
#  1   DIR-UN.TO  1734 non-null   float64
#  2   NWH-UN.TO  1734 non-null   float64
#  3   NET-UN.V   1291 non-null   float64
#  4   NSR        544 non-null    float64
#  5   BYG.L      1703 non-null   float64
#  6   SGRO.L     1702 non-null   float64
#  7   VNA.DE     1707 non-null   float64
#  8   LI.PA      1721 non-null   float64
#  9   CERT       728 non-null    float64
#  10  BRNK.DE    1707 non-null   float64
#  11  TSM1T.TL   1341 non-null   float64
#  12  CBUS       1567 non-null   float64
#  13  T82U.SI    1685 non-null   float64
#  14  ^GSPC      1702 non-null   float64
# dtypes: float64(15)
# memory usage: 216.8 KB

# %%
(all_d /all_d.iloc[0] * 100).plot(figsize=(15,6))
plt.show()
#ploting normalized data to show a fair comparision

# %%
wsb_returns = (wsb_data / wsb_data.shift(1)) - 1
wsb_returns.head()
# Out:
#             REI-UN.TO  DIR-UN.TO  NWH-UN.TO  NET-UN.V  NSR     BYG.L  \
# Date
# 2017-01-03        NaN        NaN        NaN       NaN  NaN       NaN
# 2017-01-04   0.011685   0.010689   0.000000       NaN  NaN  0.021690
# 2017-01-05   0.005216   0.000000   0.007906       NaN  NaN  0.013177
# 2017-01-06   0.003707  -0.010576  -0.000981       NaN  NaN  0.031792
# 2017-01-09  -0.004063  -0.010688  -0.003925       NaN  NaN -0.007003
#
#               SGRO.L    VNA.DE     LI.PA  CERT   BRNK.DE  TSM1T.TL  CBUS  \
# Date
# 2017-01-03       NaN       NaN       NaN   NaN       NaN       NaN   NaN
# 2017-01-04  0.014790  0.000000  0.007387   NaN  0.009989       NaN   NaN
# 2017-01-05  0.011747  0.019643  0.001765   NaN -0.003407       NaN   NaN
# 2017-01-06  0.017415 -0.004936  0.005693   NaN  0.003418       NaN   NaN
# 2017-01-09 -0.007608 -0.007200 -0.011861   NaN  0.001099       NaN   NaN
#
#              T82U.SI
# Date
# 2017-01-03       NaN
# 2017-01-04 -0.003021
# 2017-01-05  0.003030
# 2017-01-06  0.015106
# 2017-01-09  0.000000

# %%
snp_returns = (snp_data / snp_data.shift(1)) - 1
snp_returns.head()
# Out:
#                ^GSPC
# Date
# 2017-01-03       NaN
# 2017-01-04  0.005722
# 2017-01-05 -0.000771
# 2017-01-06  0.003517
# 2017-01-09 -0.003549

# %%
weights_one_to_three_internatonal  = (2+2+1+2+3+3+3+2+2+2+1+3+2+2)
print(weights_one_to_three_internatonal)
# Out:
# 30

# %%
#assiging evenly distributed weights to portfolio and s&p 500
wsb_weights = np.array([2/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal, 1/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal,3/weights_one_to_three_internatonal, 3/weights_one_to_three_internatonal, 3/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal, 1/weights_one_to_three_internatonal, 3/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal, 2/weights_one_to_three_internatonal])
snp_weights = np.array([1.0])

wsb_r = np.dot(wsb_returns, wsb_weights)
snp_r = np.dot(snp_returns, snp_weights)

print(sum(wsb_weights))
# Out:
# 0.9999999999999999

# %%
snp_annual_returns = snp_returns.mean() *250
snp_annual_returns
#s&p50 avergae annual returns
# Out:
# ^GSPC    0.119778
# dtype: float64

# %%
wsb_annual_returns = wsb_returns.mean() * 250
wsb_annual_returns
#wall street bets avergae annual returns
# Out:
# REI-UN.TO    0.025173
# DIR-UN.TO    0.143281
# NWH-UN.TO   -0.011511
# NET-UN.V     0.068492
# NSR          0.069028
# BYG.L        0.148349
# SGRO.L       0.167918
# VNA.DE       0.043888
# LI.PA        0.106974
# CERT        -0.142090
# BRNK.DE     -0.010637
# TSM1T.TL    -0.045445
# CBUS        -0.313248
# T82U.SI      0.028829
# dtype: float64

# %%
wsb_annual_return = 'WSB annual returns : ' + str(round(np.dot(wsb_annual_returns, wsb_weights), 5)*100) + ' %'
print(wsb_annual_return)
#WSB annual returns
# Out:
# WSB annual returns : 3.0669999999999997 %

# %%
snp_annual_return = 'S&P 500 annual returns : ' + str(round(np.dot(snp_annual_returns, snp_weights), 5)*100) + ' %'
print(snp_annual_return)
#S&P500 annual returns
# Out:
# S&P 500 annual returns : 11.978 %

# %% [markdown]
# # Conclusion:
#
# #### The average annual rate fo return of the internatoinal ries portfolio from the date 2017/01/01 stands at: 3.0669999999999997 %
# #### The average annual rate fo return of the S&P 500 from the date 2017/01/01 stands at: 11.978 %
#
#
# ### Summery: if one was to invest on the date 2017/01/01 X amount in to a distributed portfolio based on ratins 1, 2, 3 containing the internatonal reit stocks (investing 1/30 for rating one , 2/30 for rating 2 , 3/30 for rating three in each stock) this portfolio's performance would currently stand at a AAR of 3.0669999999999997 %.
#
# ### However investing the same amount in the S&P 500 would have given a AAR of  11.978 %. hence we conclude that those would not be better off and have  not out performed the S&P 500.

# %%
#downloading datasets
GME = yf.download('GME', start=start)['Adj Close']
AMC = yf.download('AMC', start=start)['Adj Close']
BB = yf.download('BB', start=start)['Adj Close']
SP500 = yf.download('^GSPC', start=start)['Adj Close']

# Create a DataFrame with all tickers and their adjusted close prices
all_tickers_data = pd.concat([GME, AMC, BB, SP500], axis=1)
all_tickers_data.columns = ['GME', 'AMC', 'BB', 'S&P 500']

# Calculate the portfolio by taking the average of the three stocks
wsb_portfolio_even_distribute = (all_tickers_data['GME'] + all_tickers_data['AMC'] + all_tickers_data['BB']) / 3

# Calculate the percentage gain or loss for the portfolio
portfolio_percent_gain = 100 * ((wsb_portfolio_even_distribute.iloc[-1] - wsb_portfolio_even_distribute.iloc[0]) / wsb_portfolio_even_distribute.iloc[0])

# Calculate the percentage gain or loss for the S&P 500
SP500_percent_gain = 100 * ((all_tickers_data['S&P 500'].iloc[-1] - all_tickers_data['S&P 500'].iloc[0]) / all_tickers_data['S&P 500'].iloc[0])

# Print the results
print('Portfolio percentage gain:', portfolio_percent_gain, '%')
print('S&P 500 percentage gain:', SP500_percent_gain, '%')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Portfolio percentage gain: 101.65017896864666 %
# S&P 500 percentage gain: 39.24335705358317 %

# %% [markdown]
# # Conclusion:
#
# #### The average annual rate fo return of the wall street bets portfolio from the date 2020/01/01 stands at: 113.27 %
# #### The average annual rate fo return of the S&P 500 from the date 2020/01/01 stands at: 12.152 %
#
# #### How ever as this was a volitile trade using the mean dose not give a significat insite weather this trade payed off in the long term in regards to the time frame (2020/01/01 - 2023/07/23)
#
# ### by further research we can aknowlage that in the time frame (2020/01/01 - 2023/07/23):
# #### Portfolio percentage gain: 101.65017896864666 %
# #### S&P 500 percentage gain: 39.24335705358317 %
#
# ### Summery: if one was to invest on the date 2020/01/01 X amount in to a uniformily distributed portfolio containing the stocks Game stop, AMC and black berry (investing X/3 in each stock) this portfolio's performance would currently stand at 101.65%.
#
# ### However investing the same amount in the S&P 500 would have given a gain of 39.24%. hence we conclude that those would held with "diamond hands" are still better off and have out performed the S&P 500.
